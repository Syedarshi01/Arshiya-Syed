# %% [markdown]
# Loops in Python:
#
# for
#
# while

# %%
#for loop
Date = input("Enter today's date:")
print(Date)
# Out:
# Enter today's date:26/07/2026
# 26/07/2026

# %%
#what if i want the dates of all the days from next week?
#for that i have to repeat the same line of code for 7 times. the code might get larger. so to prevent that we use these loops.
for i in range(4):      #0,1,2,3
 Phone = int(input("enter the price: "))
# Out:
# enter the price: 30000
# enter the price: 35000
# enter the price: 25000
# enter the price: 45000

# %%
nums = [1,2,3,4,5,6,7]

print(nums[0])
print(nums[1])
print(nums[2])
print(nums[3])
print(nums[4])
print(nums[5])
print(nums[6])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
nums = [1,2,3,4,5]

for i in nums:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
days = ['mon', 'tues', 'wed', 'thurs', 'fri', 'sat', 'sun']

for k in days:
  print(k)
# Out:
# mon
# tues
# wed
# thurs
# fri
# sat
# sun

# %% [markdown]
# while loop

# %% [markdown]
# while condition:
#
# statement

# %%
h = 0

while h < 6:
  print(h)
  h += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
n = 10

while n < 5:
  print(n)
  n += 1
